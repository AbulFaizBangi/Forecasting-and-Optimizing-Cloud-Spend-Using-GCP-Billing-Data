# %%
# %pip install pandas scikit-learn imbalanced-learn

import pandas as pd 
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from imblearn.over_sampling import SMOTE
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.1 MB/s eta 0:00:00
# Collecting scikit-learn
#   Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.1-py3-none-any.whl.metadata (8.9 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/abulfaiz/Documents/GitHub/GCP-Cloud-Billing-Data/Forecasting-and-Optimizing-Cloud-Spend-Using-GCP-Billing-Data/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 1.9 MB/s eta 0:00:00
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting sklearn-compat<0.2,>=0.1.5 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six>=1.5 in /Users/abulfaiz/Documents/GitHub/GCP-Cloud-Billing-Data/Forecasting-and-Optimizing-Cloud-Spend-Using-GCP-Billing-Data/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 9.4 MB/s eta 0:00:00a 0:00:01m
# Using cached scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl (8.1 MB)
# Downloading imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.4/235.4 kB 5.8 MB/s eta 0:00:00ta 0:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading numpy-2.4.3-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 6.9 MB/s eta 0:00:0000:0100:01
# Downloading scipy-1.17.1-cp311-cp311-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 4.4 MB/s eta 0:00:0000:0100:01
# Downloading sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn, sklearn-compat, imbalanced-learn
# Successfully installed imbalanced-learn-0.14.1 joblib-1.5.3 numpy-2.4.3 pandas-3.0.1 scikit-learn-1.8.0 scipy-1.17.1 sklearn-compat-0.1.5 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
finops = pd.read_csv('gcp_final_approved_dataset.csv')

# %%
finops.head()
# Out:
#     Resource ID     Service Name  Usage Quantity Usage Unit  \
# 0  res-ST6BAJ2N   Cloud Dataproc        954.9843   Requests
# 1  res-TYGNR0RV          Pub/Sub        479.6348         GB
# 2  res-S3I9C869         BigQuery        114.4129         GB
# 3  res-1RY9BZ6G  Cloud Endpoints        413.1930         GB
# 4  res-S3HQYIZ2    Cloud Spanner        335.9892         GB
#
#           Region/Zone  CPU Utilization (%)  Memory Utilization (%)  \
# 0       europe-north1                92.72                   70.42
# 1        europe-west1                37.78                   46.80
# 2  southamerica-east1                82.54                   59.47
# 3         us-central1                86.68                   97.63
# 4     asia-southeast1                82.95                   21.58
#
#    Network Inbound Data (Bytes)  Network Outbound Data (Bytes)  \
# 0                   77097035547                   8.268593e+10
# 1                    8239357017                   1.135149e+10
# 2                   23358691883                   2.345081e+10
# 3                   53404385778                   6.078019e+10
# 4                   10795270461                   1.416138e+10
#
#    Usage Start Date    Usage End Date  Cost per Quantity ($)  \
# 0  01-08-2024 22:24  07-08-2024 06:54                   5.24
# 1  23-08-2024 09:18  25-08-2024 07:26                   9.82
# 2  18-07-2024 11:13  22-07-2024 00:45                   7.37
# 3  20-07-2024 00:15  21-07-2024 10:16                   4.41
# 4  21-08-2024 21:25  25-08-2024 00:21                   6.09
#
#    Unrounded Cost ($)  Rounded Cost ($)  Total Cost (INR)
# 0             5004.12              5004            415332
# 1             4710.01              4710            390930
# 2              843.22               843             69969
# 3             1822.18              1822            151226
# 4             2046.17              2046            169818

# %%
finops.isnull().sum()
# Out:
# Resource ID                      0
# Service Name                     0
# Usage Quantity                   0
# Usage Unit                       0
# Region/Zone                      0
# CPU Utilization (%)              0
# Memory Utilization (%)           0
# Network Inbound Data (Bytes)     0
# Network Outbound Data (Bytes)    0
# Usage Start Date                 0
# Usage End Date                   0
# Cost per Quantity ($)            0
# Unrounded Cost ($)               0
# Rounded Cost ($)                 0
# Total Cost (INR)                 0
# dtype: int64
